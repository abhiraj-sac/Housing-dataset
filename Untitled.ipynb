# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('kc_house_data.csv')
df.drop(columns=['id'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.head(5)
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.nunique()
# Out:
# date              372
# price            4028
# bedrooms           13
# bathrooms          30
# sqft_living      1038
# sqft_lot         9782
# floors              6
# waterfront          2
# view                5
# condition           5
# grade              12
# sqft_above        946
# sqft_basement     306
# yr_built          116
# yr_renovated       70
# zipcode            70
# lat              5034
# long              752
# sqft_living15     777
# sqft_lot15       8689
# dtype: int64

# %%
df["date"]= pd.to_datetime(df.date)

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21608 2014-05-21  360000.0         3       2.50         1530      1131
# 21609 2015-02-23  400000.0         4       2.50         2310      5813
# 21610 2014-06-23  402101.0         2       0.75         1020      1350
# 21611 2015-01-16  400000.0         3       2.50         1600      2388
# 21612 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
df['age_of_house'] = df['year'] -df['yr_built']

# %%
df['age_of_house'].agg({'min','max','mean'})
# Out:
# mean     43.317818
# min      -1.000000
# max     115.000000
# Name: age_of_house, dtype: float64

# %%
df = df[df['age_of_house'] > 0]

# %%
df['age_of_house'].agg({'min','max','mean'})
# Out:
# mean     44.222758
# min       1.000000
# max     115.000000
# Name: age_of_house, dtype: float64

# %%
df['yr_renovated'].unique()
# Out:
# array([   0, 1991, 2002, 2010, 1999, 1992, 2013, 1994, 1978, 2005, 2008,
#        2003, 1984, 1954, 2014, 2011, 1974, 1983, 1945, 1990, 1988, 1957,
#        1977, 1981, 1995, 2000, 1998, 1970, 1989, 2004, 1986, 2009, 2007,
#        1987, 1973, 2006, 1985, 2001, 1980, 1971, 1979, 1997, 1950, 1969,
#        1948, 2015, 1968, 2012, 1963, 1951, 1993, 1962, 1996, 1972, 1953,
#        1955, 1982, 1956, 1940, 1976, 1946, 1975, 1958, 1964, 1959, 1960,
#        1967, 1965, 1934, 1944], dtype=int64)

# %%
(df['yr_renovated'].value_counts(normalize=True)*100).head()
# Means 95 of the data of year_renovated is not there
# Out:
# yr_renovated
# 0       95.682774
# 2014     0.429833
# 2013     0.174767
# 2003     0.170044
# 2005     0.165320
# Name: proportion, dtype: float64

# %%
plt.scatter(df['yr_renovated'],df['price'])
plt.show()

# %%
df.drop(columns=['yr_renovated'],axis=1,inplace=True)
# Out:
# C:\Users\Abhi\AppData\Local\Temp\ipykernel_3088\2193884466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['yr_renovated'],axis=1,inplace=True)

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21608 2014-05-21  360000.0         3       2.50         1530      1131
# 21609 2015-02-23  400000.0         4       2.50         2310      5813
# 21610 2014-06-23  402101.0         2       0.75         1020      1350
# 21611 2015-01-16  400000.0         3       2.50         1600      2388
# 21612 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
df.corr()
# Out:
#                    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date           1.000000 -0.003734 -0.014490  -0.029960    -0.031706  0.004415
# price         -0.003734  1.000000  0.305629   0.522404     0.701616  0.091508
# bedrooms      -0.014490  0.305629  1.000000   0.512674     0.572340  0.033111
# bathrooms     -0.029960  0.522404  0.512674   1.000000     0.753584  0.092015
# sqft_living   -0.031706  0.701616  0.572340   0.753584     1.000000  0.176755
# sqft_lot       0.004415  0.091508  0.033111   0.092015     0.176755  1.000000
# floors        -0.014347  0.255283  0.174261   0.499194     0.354732  0.001006
# waterfront     0.001183  0.265940 -0.005537   0.064497     0.104691  0.021517
# view          -0.003529  0.400997  0.081446   0.192433     0.288517  0.073944
# condition     -0.056194  0.042199  0.034137  -0.116441    -0.051818 -0.012057
# grade         -0.035744  0.666420  0.353954   0.662616     0.763403  0.118207
# ...

# %%
plt.figure(figsize=(10,10))
plt.hist(df['price'], bins =150 , color = "g" ,density =True)
plt.hist(df['price'], bins =150 , color = "b" ,density =True , histtype='step' )
plt.show()

# %%
sns.set(rc ={"figure.figsize":(10,5)})
sns.scatterplot(data=df,x="age_of_house",y="price")
plt.show()

# %%
df.head(5)
sns.lineplot(data=df,x='floors',y='price')
plt.show()

# %%
df['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
plt.pie(df['floors'].value_counts(normalize =True) ,explode=[0.2,0,0,0,0,1],labels=df['floors'].value_counts().index,
        autopct ="%.2f%%"
       )
plt.show()

# %%
df.head()
sns.violinplot(data=df,x='waterfront',y='price')
# sns.lineplot(data=df,x='waterfront',y='price')
plt.show()

# %%
sns.violinplot(data=df,x='waterfront',y='price',hue='view')
plt.show()
# view - An index from 0 to 4 of how good the view of the property was 0 = No view, 1 = Fair 2 = Average, 3 = Good, 4 = Excellent

# %%
plt.figure(figsize =(10 , 7))
plt.subplot(2,1,1)
sns.scatterplot(data=df,x='sqft_living',y='price',hue='view')
plt.show()
sns.scatterplot(data=df,x='sqft_lot',y='price',hue='view')
plt.show()

# %% [markdown]
# # Its crystal clear that with view and area of the house also have the positive correlation with price and
# # it will help ML model in prediction

# %%
df.drop("zipcode" , axis =1 , inplace =True)
# Out:
# C:\Users\Abhi\AppData\Local\Temp\ipykernel_3088\615697414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("zipcode" , axis =1 , inplace =True)

# %%
df.head(5)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df.head(2)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
#
#        lat     long  sqft_living15  sqft_lot15  year  age_of_house
# 0  47.5112 -122.257           1340        5650  2014            59
# 1  47.7210 -122.319           1690        7639  2014            63

# %%
# sns.scatterplot(data=df,x='bathrooms',y="price")
# plt.show()
sns.scatterplot(data=df,x='bedrooms',y="price")
plt.show()
# quite linear it is 
df = df[df['bedrooms'] < 30]

# %%
sns.lineplot(data=df,x='view',y="price")
plt.show()\
# it will help linear regression

# %%
plt.figure(figsize =(15,7))
sns.heatmap(df.corr() , annot =False , linewidth =0.2)
# Out:
# <Axes: >

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: >

# %%
def tukey(data):
    q1, q3 = np.percentile(data,[25,75])
    iqr = q3 - q1
    lower = q1 - (iqr*1.5)
    upper = q3 - (iqr*1.5)
    
    return np.where((data > upper) | (data < lower))

# %%
# noise_index = pd.Series()
noise_index = pd.Series(tukey(df['price']))
# df.drop(noise_index )
# df.head(5)

# %%
# noise_index.shape
cop = df.copy()

# %%
df.drop(columns=['date','yr_built','sqft_living15','sqft_lot15'],axis=1,inplace=True)
df.head(5)
# Out:
# C:\Users\Abhi\AppData\Local\Temp\ipykernel_3088\3064472417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['date','yr_built','sqft_living15','sqft_lot15'],axis=1,inplace=True)
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement      lat     long  year  \
# ...

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement      lat  \
# ...

# %%
sns.violinplot(data=df,x='grade',y="price")
plt.show()

# %%
df.corr()
df.drop(columns=['bedrooms','sqft_lot'],axis=1,inplace=True)
# Out:
#                   price    floors  waterfront      view  condition     grade  \
# price          1.000000  0.255301    0.265941  0.401003   0.042173  0.666433
# floors         0.255301  1.000000    0.025484  0.035289  -0.254327  0.452705
# waterfront     0.265941  0.025484    1.000000  0.400405   0.016376  0.082674
# view           0.401003  0.035289    0.400405  1.000000   0.043853  0.256287
# condition      0.042173 -0.254327    0.016376  0.043853   1.000000 -0.136266
# grade          0.666433  0.452705    0.082674  0.256287  -0.136266  1.000000
# sqft_above     0.604962  0.527323    0.073632  0.172308  -0.151006  0.756871
# sqft_basement  0.326846 -0.243834    0.079493  0.275619   0.172354  0.173415
# lat            0.305497  0.047931   -0.014312  0.006470  -0.015708  0.113453
# long           0.021269  0.133196   -0.042577 -0.079758  -0.107100  0.200557
# year           0.006843 -0.008926   -0.004499 -0.001038  -0.053476 -0.022450
# ...

# %%
df.corr()
X = df.drop(columns=['price'])
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)
X_test
# Out:
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 1468      1.0           0     0          3      7        1140            250
# 21137     2.0           0     0          3      7        1150              0
# 16670     2.0           0     0          3     11        3010              0
# 11391     1.0           0     0          3      8        1560              0
# 1125      1.0           0     0          4      7        1010           1010
# ...       ...         ...   ...        ...    ...         ...            ...
# 20717     3.0           0     0          3      7        1320              0
# 16430     2.0           0     3          3     10        4150           1710
# 5622      1.0           0     0          3      7        1210            570
# 13599     1.5           0     0          3      8        1780              0
# 5252      2.0           0     0          4      8        2080              0
#
#            lat     long  year  age_of_house
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred =lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6931725457646065

# %%
lr.predict([[1.0,0,0,3,7,1140,250,47.7224,-122.332,2014,49]])
# Out:
# C:\Users\Abhi\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([416981.68812734])

# %%
df[df.index == 1468]
# Out:
#          price  floors  waterfront  view  condition  grade  sqft_above  \
# 1468  400000.0     1.0           0     0          3      7        1140
#
#       sqft_basement      lat     long  year  age_of_house
# 1468            250  47.7224 -122.332  2014            49

# %%
# its working really fine !!
